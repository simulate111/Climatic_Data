# %% [markdown]
# <a href="https://colab.research.google.com/github/simulate111/General/blob/main/Turku_era5_land_hourly_time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install "cdsapi>=0.7.7"
# !pip install netcdf4
# !pip install netcdf4 h5netcdf
# Out:
# Collecting cdsapi>=0.7.7
#   Downloading cdsapi-0.7.7-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting ecmwf-datastores-client>=0.4.0 (from cdsapi>=0.7.7)
#   Downloading ecmwf_datastores_client-0.4.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from cdsapi>=0.7.7) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cdsapi>=0.7.7) (4.67.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7) (25.4.0)
# Collecting multiurl>=0.3.7 (from ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7)
#   Downloading multiurl-0.3.7-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi>=0.7.7) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi>=0.7.7) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi>=0.7.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi>=0.7.7) (2025.11.12)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.7) (1.17.0)
# Downloading cdsapi-0.7.7-py2.py3-none-any.whl (12 kB)
# Downloading ecmwf_datastores_client-0.4.1-py3-none-any.whl (29 kB)
# Downloading multiurl-0.3.7-py3-none-any.whl (21 kB)
# Installing collected packages: multiurl, ecmwf-datastores-client, cdsapi
# Successfully installed cdsapi-0.7.7 ecmwf-datastores-client-0.4.1 multiurl-0.3.7
# Collecting netcdf4
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting cftime (from netcdf4)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2.0.2)
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 86.5 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.7 MB/s eta 0:00:00
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.6.5 netcdf4-1.7.3
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netcdf4) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf) (3.15.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from h5netcdf) (25.0)

# %%
import os

# Updated configuration: removed the UID prefix as per the error instructions
content = """url: https://cds.climate.copernicus.eu/api
key: c025f203-5930-4d9c-acd6-699c46be7fd8"""

with open(os.path.expanduser('~/.cdsapirc'), 'w') as f:
    f.write(content)

print("Configuration updated! Now attempting to update the library...")

# Also update your library to the latest version to match the new API
# !pip install --upgrade cdsapi
# Out:
# Configuration updated! Now attempting to update the library...
# Requirement already satisfied: cdsapi in /usr/local/lib/python3.12/dist-packages (0.7.7)
# Requirement already satisfied: ecmwf-datastores-client>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from cdsapi) (0.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from cdsapi) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cdsapi) (4.67.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (25.4.0)
# Requirement already satisfied: multiurl>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (0.3.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.5.0->cdsapi) (2025.11.12)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (1.17.0)

# %%
#@title 📍 Select City and View Map { run: "auto" }

# 1. Selection Menu
# Use the dropdown on the right to choose the city
selected_city = "Turku" #@param ["Turku", "Copenhagen", "Stockholm", "Oslo"]

# 2. City Coordinate Database
city_db = {
    "Turku": {"lat": 60.5, "lon": 22.3, "color": "red"},
    "Copenhagen": {"lat": 55.7, "lon": 12.6, "color": "blue"},
    "Stockholm": {"lat": 59.3, "lon": 18.1, "color": "green"},
    "Oslo": {"lat": 59.9, "lon": 10.7, "color": "purple"}
}

# Get current selection
coords = city_db[selected_city]
print(f"Current Selection: {selected_city} ({coords['lat']}, {coords['lon']})")

# 3. Generate Map showing all options
import folium
m = folium.Map(location=[59.0, 16.0], zoom_start=5, tiles='cartodbpositron')

for city, data in city_db.items():
    is_selected = (city == selected_city)
    folium.Marker(
        [data['lat'], data['lon']],
        popup=f"<b>{city}</b>",
        tooltip=city,
        icon=folium.Icon(color=data['color'], icon='star' if is_selected else 'info-sign')
    ).add_to(m)

m
# Out:
# Current Selection: Turku (60.5, 22.3)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab588348c3986980429ff6dc2118742b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab588348c3986980429ff6dc2118742b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab588348c3986980429ff6dc2118742b = L.map(
#                 &quot;map_ab588348c3986980429ff6dc2118742b&quot;,
#                 {
#                     center: [59.0, 16.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_807232e0e484b50f54ce7d54cbf48cb9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_807232e0e484b50f54ce7d54cbf48cb9.addTo(map_ab588348c3986980429ff6dc2118742b);
#
#
#             var marker_1fe491cbfee4a4d2b8f24170c38ff017 = L.marker(
#                 [60.5, 22.3],
#                 {
# }
#             ).addTo(map_ab588348c3986980429ff6dc2118742b);
#
#
#             var icon_c40a94df188061a050f31859a20ce13a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_32fea7f000bda7eae17c1f35be55d3db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71fdde63b109b8cd45e2da14539a1ed3 = $(`&lt;div id=&quot;html_71fdde63b109b8cd45e2da14539a1ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Turku&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_32fea7f000bda7eae17c1f35be55d3db.setContent(html_71fdde63b109b8cd45e2da14539a1ed3);
#
#
#
#         marker_1fe491cbfee4a4d2b8f24170c38ff017.bindPopup(popup_32fea7f000bda7eae17c1f35be55d3db)
#         ;
#
#
#
#
#             marker_1fe491cbfee4a4d2b8f24170c38ff017.bindTooltip(
#                 `&lt;div&gt;
#                      Turku
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1fe491cbfee4a4d2b8f24170c38ff017.setIcon(icon_c40a94df188061a050f31859a20ce13a);
#
#
#             var marker_f36cb7e58148e3a7a195077430b88042 = L.marker(
#                 [55.7, 12.6],
#                 {
# }
#             ).addTo(map_ab588348c3986980429ff6dc2118742b);
#
#
#             var icon_5f8ed7cc92013e5f19aac48227c8b1c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0ac305757cc82f9e5a7a14f584d0ce1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18ac3c71efb67e7ee423a3dd512b336c = $(`&lt;div id=&quot;html_18ac3c71efb67e7ee423a3dd512b336c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Copenhagen&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_0ac305757cc82f9e5a7a14f584d0ce1d.setContent(html_18ac3c71efb67e7ee423a3dd512b336c);
#
#
#
#         marker_f36cb7e58148e3a7a195077430b88042.bindPopup(popup_0ac305757cc82f9e5a7a14f584d0ce1d)
#         ;
#
#
#
#
#             marker_f36cb7e58148e3a7a195077430b88042.bindTooltip(
#                 `&lt;div&gt;
#                      Copenhagen
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f36cb7e58148e3a7a195077430b88042.setIcon(icon_5f8ed7cc92013e5f19aac48227c8b1c9);
#
#
#             var marker_e27b8fb26135ca44b1d53059cc2f037e = L.marker(
#                 [59.3, 18.1],
#                 {
# }
#             ).addTo(map_ab588348c3986980429ff6dc2118742b);
#
#
#             var icon_9abbb2a406c05b88628961e6b220d5a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d6101b2ddf373591814c70748f436334 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf2e890d3e61a18bca663116f77f522 = $(`&lt;div id

# %%
import cdsapi
import os
import calendar

# Setting up the variables based on your selection above
LAT = city_db[selected_city]['lat']
LON = city_db[selected_city]['lon']
folder_city = selected_city.lower()

c = cdsapi.Client(progress=False)
tasks = [('2024', str(m).zfill(2)) for m in range(1, 13)] + [('2025', '01')]

print(f"--- 📥 Downloading data for: {selected_city} ---")

for i, (year, month) in enumerate(tasks):
    filename = f'{folder_city}_{year}_{month}.nc'

    if os.path.exists(filename):
        continue

    # Date logic for 2024 vs 2025
    last_day = 1 if year == '2025' else calendar.monthrange(int(year), int(month))[1]
    days = [str(d).zfill(2) for d in range(1, last_day + 1)]

    try:
        c.retrieve(
            'reanalysis-era5-land',
            {
                'variable': ['2m_temperature', '10m_u_component_of_wind',
                             '10m_v_component_of_wind', 'surface_solar_radiation_downwards'],
                'year': year, 'month': month, 'day': days,
                'time': [f"{str(h).zfill(2)}:00" for h in range(24)],
                'area': [LAT, LON, LAT, LON],
                'format': 'netcdf',
            },
            filename)
        print(f"✅ {filename} done.")
    except Exception as e:
        print(f"❌ Failed {year}-{month}: {e}")

print(f"--- 🎉 All {selected_city} downloads complete ---")
# Out:
# 2025-12-20 10:40:03,892 INFO [2025-12-03T00:00:00Z] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# INFO:ecmwf.datastores.legacy_client:[2025-12-03T00:00:00Z] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# --- 📥 Downloading data for: Turku ---
# 2025-12-20 10:40:04,274 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:40:04,277 INFO Request ID is d366eeb7-9e5c-4bae-a157-97d863f28dc1
# INFO:ecmwf.datastores.legacy_client:Request ID is d366eeb7-9e5c-4bae-a157-97d863f28dc1
# 2025-12-20 10:40:04,459 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:40:37,863 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_01.nc done.
# 2025-12-20 10:40:40,258 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:40:40,261 INFO Request ID is 60103198-9fd5-47a1-9e8c-4341244e4442
# INFO:ecmwf.datastores.legacy_client:Request ID is 60103198-9fd5-47a1-9e8c-4341244e4442
# 2025-12-20 10:40:40,591 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:40:54,690 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-12-20 10:41:02,511 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_02.nc done.
# 2025-12-20 10:41:04,768 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:41:04,770 INFO Request ID is dcf6706d-2e6d-449e-a575-b169f0dcac42
# INFO:ecmwf.datastores.legacy_client:Request ID is dcf6706d-2e6d-449e-a575-b169f0dcac42
# 2025-12-20 10:41:04,960 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:47:26,354 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_03.nc done.
# 2025-12-20 10:47:28,752 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:47:28,754 INFO Request ID is fa3dd445-d71a-4a09-9cfc-d6fa4b356d0b
# INFO:ecmwf.datastores.legacy_client:Request ID is fa3dd445-d71a-4a09-9cfc-d6fa4b356d0b
# 2025-12-20 10:47:28,931 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:48:19,650 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_04.nc done.
# 2025-12-20 10:48:22,074 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:48:22,077 INFO Request ID is 08720f87-1172-42e0-bf26-a3a956c33651
# INFO:ecmwf.datastores.legacy_client:Request ID is 08720f87-1172-42e0-bf26-a3a956c33651
# 2025-12-20 10:48:22,253 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:48:44,291 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_05.nc done.
# 2025-12-20 10:48:46,508 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:48:46,510 INFO Request ID is ab90b5a6-18f4-4057-9e9b-f489cefec595
# INFO:ecmwf.datastores.legacy_client:Request ID is ab90b5a6-18f4-4057-9e9b-f489cefec595
# 2025-12-20 10:48:46,685 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:49:08,597 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_06.nc done.
# 2025-12-20 10:49:11,179 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:49:11,181 INFO Request ID is 433fd359-56a7-4b73-9865-b21dc82499df
# INFO:ecmwf.datastores.legacy_client:Request ID is 433fd359-56a7-4b73-9865-b21dc82499df
# 2025-12-20 10:49:11,368 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:49:44,831 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_07.nc done.
# 2025-12-20 10:49:47,272 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:49:47,275 INFO Request ID is ddd48156-7950-4426-b0a0-2996d78f57db
# INFO:ecmwf.datastores.legacy_client:Request ID is ddd48156-7950-4426-b0a0-2996d78f57db
# 2025-12-20 10:49:47,465 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:50:20,889 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-12-20 10:50:38,155 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_08.nc done.
# 2025-12-20 10:50:40,581 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:50:40,583 INFO Request ID is 1b92a371-2163-4374-8000-0ec5b994cf2f
# INFO:ecmwf.datastores.legacy_client:Request ID is 1b92a371-2163-4374-8000-0ec5b994cf2f
# 2025-12-20 10:50:40,762 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:50:49,634 INFO status has been updated to running
# INFO:ecmwf.datastores.legacy_client:status has been updated to running
# 2025-12-20 10:50:54,900 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_09.nc done.
# 2025-12-20 10:50:57,366 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:50:57,369 INFO Request ID is e3e82f24-4b2e-44f2-85ee-3f97cdb0f4de
# INFO:ecmwf.datastores.legacy_client:Request ID is e3e82f24-4b2e-44f2-85ee-3f97cdb0f4de
# 2025-12-20 10:50:57,542 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:51:30,930 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_10.nc done.
# 2025-12-20 10:51:33,457 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:51:33,459 INFO Request ID is 55e5d171-12d7-4c1b-b042-e3877e24db24
# INFO:ecmwf.datastores.legacy_client:Request ID is 55e5d171-12d7-4c1b-b042-e3877e24db24
# 2025-12-20 10:51:33,639 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:51:48,102 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_11.nc done.
# 2025-12-20 10:51:50,427 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:51:50,430 INFO Request ID is 1eed4442-2e8c-457e-9fc9-33dde90c12d6
# INFO:ecmwf.datastores.legacy_client:Request ID is 1eed4442-2e8c-457e-9fc9-33dde90c12d6
# 2025-12-20 10:51:50,626 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:52:04,884 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2024_12.nc done.
# 2025-12-20 10:52:07,319 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# INFO:ecmwf.datastores.legacy_client:[2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2025-12-20 10:52:07,322 INFO Request ID is 73854b5c-3efd-4c0f-b37c-32baede35ff9
# INFO:ecmwf.datastores.legacy_client:Request ID is 73854b5c-3efd-4c0f-b37c-32baede35ff9
# 2025-12-20 10:52:07,500 INFO status has been updated to accepted
# INFO:ecmwf.datastores.legacy_client:status has been updated to accepted
# 2025-12-20 10:52:29,314 INFO status has been updated to successful
# INFO:ecmwf.datastores.legacy_client:status has been updated to successful
# ✅ turku_2025_01.nc done.
# --- 🎉 All Turku downloads complete ---

# %%
#@title 📊 Step 3: Process and Export CSV
import xarray as xr
import pandas as pd
import numpy as np
import glob
import os
import zipfile

file_pattern = f'{selected_city.lower()}_*.nc'
file_list = sorted(glob.glob(file_pattern))
extract_dir = 'extracted_temp'
os.makedirs(extract_dir, exist_ok=True)
all_data = []

print(f"--- Processing {len(file_list)} files for {selected_city} ---")

for f in file_list:
    try:
        # Check for ZIP signature 'PK'
        with open(f, 'rb') as test_f:
            is_zip = test_f.read(2) == b'PK'

        if is_zip:
            with zipfile.ZipFile(f, 'r') as zip_ref:
                zip_ref.extractall(extract_dir)
            inner_files = glob.glob(os.path.join(extract_dir, "*.nc"))
            if inner_files:
                ds = xr.open_dataset(inner_files[0], engine='netcdf4')
                df = ds.to_dataframe().reset_index()
                all_data.append(df)
                for extra in inner_files: os.remove(extra)
        else:
            ds = xr.open_dataset(f, engine='netcdf4')
            df = ds.to_dataframe().reset_index()
            all_data.append(df)
        print(f"✅ Processed: {f}")
    except Exception as e:
        print(f"❌ Error on {f}: {e}")

if all_data:
    df_combined = pd.concat(all_data).sort_values('valid_time')
    df_combined['valid_time'] = pd.to_datetime(df_combined['valid_time'])

    # 1. Formatting and Unit Conversions
    df_combined['Date'] = df_combined['valid_time'].dt.strftime('%Y-%m-%d')
    df_combined['Hour'] = df_combined['valid_time'].dt.strftime('%H:00')
    df_combined['Temperature_C'] = df_combined['t2m'] - 273.15
    df_combined['Wind_Speed_ms'] = np.sqrt(df_combined['u10']**2 + df_combined['v10']**2)
    df_combined['GHI_Wm2'] = df_combined['ssrd'] / 3600

    # 2. Final Export
    final_output = df_combined[['Date', 'Hour', 'Temperature_C', 'Wind_Speed_ms', 'GHI_Wm2']]
    csv_name = f'{selected_city}_Weather_Hourly_2024.csv'
    final_output.to_csv(csv_name, index=False)

    print(f"\nSUCCESS: Saved to {csv_name}")
    print(final_output.head())
else:
    print("No data frames found.")
# Out:
# --- Processing 13 files for Turku ---
# ✅ Processed: turku_2024_01.nc
# ✅ Processed: turku_2024_02.nc
# ✅ Processed: turku_2024_03.nc
# ✅ Processed: turku_2024_04.nc
# ✅ Processed: turku_2024_05.nc
# ✅ Processed: turku_2024_06.nc
# ✅ Processed: turku_2024_07.nc
# ✅ Processed: turku_2024_08.nc
# ✅ Processed: turku_2024_09.nc
# ✅ Processed: turku_2024_10.nc
# ✅ Processed: turku_2024_11.nc
# ✅ Processed: turku_2024_12.nc
# ✅ Processed: turku_2025_01.nc
#
# SUCCESS: Saved to Turku_Weather_Hourly_2024.csv
#          Date   Hour  Temperature_C  Wind_Speed_ms     GHI_Wm2
# 0  2024-01-01  00:00     -14.486420       2.236743  169.474442
# 1  2024-01-01  01:00     -14.128998       2.165980    0.000000
# 2  2024-01-01  02:00     -13.787689       2.090343    0.000000
# 3  2024-01-01  03:00     -13.063324       2.009852    0.000000
# 4  2024-01-01  04:00     -12.227142       2.373250    0.000000
